# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.subplot()
# Out:
# <AxesSubplot:>

# %%
plt.show()

# %%
x=[0,7,5,2,8,10]
y=[0,10,20,30,40,50]
plt.plot(x,y)
plt.show()

# %%
x=np.arange(0,100)
y=9*x+7

plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
z=np.cos(x)
plt.plot(x,z)
plt.show()

# %%
z=np.tan(x)
plt.plot(x,z)
plt.show()

# %%
x1=[6,8,9,3]
x2=[12,15,18,10,5]

y1=[7,10,4,5]
y2=[19,16,18,7,19]

plt.plot(x1,y1)
plt.plot(x2,y2)
plt.show()

# %%
plt.plot(x1,y1,c='g')
plt.plot(x2,y2,c='r')
plt.show()

# %%
plt.plot(x1,y1,c='g',label='Plot 1')
plt.plot(x2,y2,c='r',label='Plot 2')
plt.legend()
plt.show()

# %%
data=pd.read_csv('plb.csv')

# %%
data
# Out:
#       Unnamed: 0  Bronze  Gold  Silver
# 0  United States      67   137      52
# 1        Germany      67    47      43
# 2  Great Britain      26    64      55
# 3         Russia      35    50      28
# 4          China      35    44      30
# 5         France      21    20      55
# 6      Australia      25    23      34
# 7          Italy      24     8      38
# 8         Canada      61     4       4
# 9          Japan      34    17      13
